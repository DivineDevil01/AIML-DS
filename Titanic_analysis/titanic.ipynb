# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import numpy as np

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler

# %%
df_train = pd.read_csv("train.csv")

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_train.shape
# Out:
# (891, 12)

# %%
df_train["Survived"].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df_train["Survived"].value_counts(normalize=True)
# Out:
# Survived
# 0    0.616162
# 1    0.383838
# Name: proportion, dtype: float64

# %%
sns.barplot(x="Sex", y="Survived", data=df_train)
plt.xlabel("gender")
plt.ylabel("survived")
plt.title("Gender vs survived")
plt.show()

# %%
df_train["Family_members"] = df_train["SibSp"] + df_train["Parch"] + 1

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Family_members
# 0      0         A/5 21171   7.2500   NaN        S               2
# 1      0          PC 17599  71.2833   C85        C               2
# 2      0  STON/O2. 3101282   7.9250   NaN        S               1
# ...

# %%
sns.boxplot(x= "Survived", y = "Family_members", data=df_train)
plt.xlabel("survived")
plt.ylabel("distribution of family member")
plt.show()

# %%
cat_col = ["Sex"]
num_col = ["Pclass","Age","Fare","Family_members"]
target = ["Survived"]

# %%
print(cat_col)
print(type(cat_col))
print(len(cat_col))
# Out:
# ['Sex']
# <class 'list'>
# 1

# %%
x_train = df_train[cat_col + num_col].copy()
y_train = df_train["Survived"]

# %%
x_train.isnull().sum()
# Out:
# Sex                 0
# Pclass              0
# Age               177
# Fare                0
# Family_members      0
# dtype: int64

# %%
x_train["Age"] = x_train["Age"].fillna(x_train["Age"].median())

# %%
age_meadian = x_train["Age"].median()

# %%
encoder = OneHotEncoder(
    categories=[
        [
        "male",
        "female"
        ]
    ],
    drop= "first",
    sparse_output= False
)

# %%
preproccessor = ColumnTransformer(
    transformers=[
        ("cat", encoder, cat_col),
        ("num", StandardScaler(), num_col)
    ]
)

# %%
model_pipline = Pipeline(
    steps=[
        ("preprossing",preproccessor),
        ("model", LogisticRegression(max_iter=1000))
    ]
)

# %%
print(x_train.shape)
print(x_train.columns)
# Out:
# (891, 5)
# Index(['Sex', 'Pclass', 'Age', 'Fare', 'Family_members'], dtype='object')

# %%
x_train["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
model_pipline.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('preprossing',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(categories=[['male',
#                                                                              'female']],
#                                                                 drop='first',
#                                                                 sparse_output=False),
#                                                   ['Sex']),
#                                                  ('num', StandardScaler(),
#                                                   ['Pclass', 'Age', 'Fare',
#                                                    'Family_members'])])),
#                 ('model', LogisticRegression(max_iter=1000))])

# %%
df_test =pd.read_csv("test.csv")

# %%
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.1+ KB

# %%
df_test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df_test["Family_members"] = df_test["SibSp"] + df_test["Parch"] + 1

# %%
cat_col1 = ["Sex"]
num_col2 = ["Pclass","Age","Fare","Family_members"]
target1 = ["Survived"]

# %%
x_test = df_test[cat_col + num_col].copy()

# %%
fare_median = x_train["Fare"].median()

# %%
x_test["Age"] = x_test["Age"].fillna(age_meadian)
x_test["Fare"] = x_test["Fare"].fillna(age_meadian)

# %%
x_test.isnull().sum()
# Out:
# Sex               0
# Pclass            0
# Age               0
# Fare              1
# Family_members    0
# dtype: int64

# %%
y_pred = model_pipline.predict(x_test)
y_prob = model_pipline.predict_proba(x_test)[:, 1]

# %%
y_pred.shape
# Out:
# (418,)

# %%
submission = pd.DataFrame({
    "PassengerId": df_test["PassengerId"],
    "Survived": y_pred
})

# %%
submission.to_csv("submission.csv", index=False)

# %%
submission.shape
# Out:
# (418, 2)

# %%
submission.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         1

# %%
submission["Survived"].value_counts()
# Out:
# Survived
# 0    260
# 1    158
# Name: count, dtype: int64
