# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("StudentsPerformance.csv")

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.shape
# Out:
# (1000, 8)

# %%
plt.hist(x = "math_score")
plt.xlable("math score")
plt.ylable("Numbe of student")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 plt.hist(x = "math_score")
#       2 plt.xlable("math score")
#       3 plt.ylable("Numbe of student")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\_api\__init__.py:218, in caching_module_getattr.<locals>.__getattr__(name)
#     216 if name in props:
#     217     return props[name].__get__(instance)
# --> 218 raise AttributeError(
#     219     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'hist'

# %%
plt.histogram(df["math_score"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 plt.histogram(df["math_score"])
#       2 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'histogram'

# %%
plt.hist(df[:5])
plt.show()

# %%
sns.histplot(df[:5], bins=30, kde=True)
plt.show()

# %%
sns.histplot(df["math score"], bins=20)
plt.xlabel("math_score")
plt.ylabel("Frequency")
plt.title("math_score Distribution")
plt.show()

# %%
sns.boxplot(x = "gender", y = "math score", data=df)
plt.xlabel("gender")
plt.ylabel("math score")
plt.title("Gender vs math score plot")
plt.show()

# %%
sns.pairplot(df[["math score", "reading score", "writing score"]])
plt.show()

# %%
sns.scatterplot(x = "reading score", y = "math score", data = df)
plt.xlabel("reading score")
plt.ylabel("math score")
plt.show()

# %%
sns.scatterplot(x = "writing score", y = "math score", data = df)
plt.xlabel("reading score")
plt.ylabel("math score")
plt.show()

# %%
sns.scatterplot(x = "reading score", y = "writing score", data = df)
plt.xlabel("reading score")
plt.ylabel("math score")
plt.show()

# %%
sns.boxplot(x = "race/ethnicity", y = "math score", data=df)
plt.xlabel("gender")
plt.ylabel("math score")
plt.title("Gender vs math score plot")
plt.show()

# %%
sns.boxplot(x = "parental level of education", y = "math score", data=df)
plt.xlabel("gender")
plt.ylabel("math score")
plt.title("Gender vs math score plot")
plt.show()

# %%
sns.boxplot(x = "lunch", y = "math score", data=df)
plt.xlabel("gender")
plt.ylabel("math score")
plt.title("Gender vs math score plot")
plt.show()

# %%
sns.boxplot(x = "test preparation course", y = "math score", data=df)
plt.xlabel("gender")
plt.ylabel("math score")
plt.title("Gender vs math score plot")
plt.show()
